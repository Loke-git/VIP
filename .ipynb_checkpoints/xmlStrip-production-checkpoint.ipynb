# %% [markdown]
# # Ibsens xmlStrip - *«fjerner buskvekster!»*
# Versjon: *0.1.3 Dvergbjerk*
#
# Dato: 09.03.2022
#
# Forfatter: vit.ass. Loke Sjølie

# %%
import time
print("Dette programmet tar XML-filer med Ibsenstruktur og gjør dem om til rentekstfiler. Trykk STOPP nå om du ikke vil kjøre.")
print("Har du husket å sette riktige parametre i cellen under?")
time.sleep(3)
# Out:
# Dette programmet tar XML-filer med Ibsenstruktur og gjør dem om til rentekstfiler. Trykk STOPP nå om du ikke vil kjøre.
# Har du husket å sette riktige parametre i cellen under?

# %% [markdown]
# # Parametre
# Under har du parametre for konversjonen.
#
# ## his:hisdel
# tag_hisdel kontrollerer følgende undertagger: *overwritten*, *overstrike*, *diagonalOverstrike*. Om tag_hisdel = 2 erstattes alle hisdel-taggene med markdown (~), om tag_hisdel = 1 slettes alle helt, og om tag_hisdel er 0 kontrolleres hver type av sin egen verdi. Dvs at GRUPPEN tar prioritet over individuell tagg.
#
# BUG: 2 fungerer ikke... helt. Vet ikke hvorfor. Den finner his:hisdel-taggen(e), men erstatningen inntreffer ikke. Må sannsynligvis bruke en annen metode for å erstatte. Det kan også være fordi disse hisdel-taggene kan være nøstet inni hverandre, kanskje.

# %%
# 0 gjør ingenting, 1 sletter taggen med innholdet HELT, 2 beholder innholdet med markdown (~~)
# Gruppekontroll
tag_hisdel = 1

# Individuell kontroll - brukes kun dersom gruppekontroll er 0
# DISSE FUNGERER IKKE ENDA - BRUK GRUPPEKONTROLL 1 ELLER 2, 3 FOR Å DEAKTIVERE. IKKE 0
tag_overwritten = 1
tag_overstrike = 1
tag_diagonaloverstrike = 1

# %% [markdown]
# ## Filformat
# Parametre for å kontrollere hvilket format som skal produseres. Merk at programmet ikke sletter eksisterende filer. Anbefaler å slette alt i output-folderen før det kjøres.

# %%
filsuffiks = "_SANERT" # Teksten som skal opptre etter hvert filnavn.
filformat = ".txt" # Formatet på de bearbeidede filene. Anbefaler .txt eller .md.

# %% [markdown]
# ## Tagger
# Parametre for å kontrollere hvilke tagger som skal slettes helt *med* innhold.

# %%
#Hvilke tagger skal utraderes MED innhold?
tags_to_erase = ["fw","handnote","teiheader","lb","figure","pb","front","note","anchor","back"] # Front erstattes av rollelisten
#replacemode = "ordinary" # ordinary/regex

# %% [markdown]
# # Program
# Ikke rør noe under om du ikke vet hva du gjør (med mindre du vet hvordan du spammer undo til det fungerer igjen ;). ).
#
# ## Bibliotek

# %%
from bs4 import BeautifulSoup # Hent BeautifulSoup-modulen (https://www.crummy.com/software/BeautifulSoup/)
import re # Requests. Brukes i noen regex-funksjoner, gitt
import os # Filsystem for lasting og lagring
import codecs # Dekoder for ASCII
import csv # CSV-leser for ASCII

# %% [markdown]
# ## Oversett ASCII

# %%
file = open('translation.csv') # Egendefinert fil fra DTD. &nbsp, &shy og &tu20 er manuelt oversatt til [mellomrom], [-] og [mellomrom].
# Andre diverse entiteter som manglet er også oversatt.
csvreader = csv.reader(file) # Importer  filen over
asciis = [] # Array for unicode-greier (eks. \u0023)
codes = [] # Array for ting som &nbsp - "html"-koder
for row in csvreader: # For hver rad
    htmlcode = row[0] # Html-tagger (de som er synlige i teksten)
    unicode = row[1] # Unicode (eg \u0023)
    ASCII = codecs.decode(unicode, 'unicode_escape') # Gjør om til ASCII
    asciis.append(ASCII) # Legg till i array
    codes.append(htmlcode)
    print(htmlcode,"=>",ASCII)
# Out:
# &half; => ½
# &#x0254; => ɔ
# &frac12; => ½
# &frac14; => ¼
# &frac34; => ¾
# &frac18; => ⅛
# &frac38; => ⅜
# &frac58; => ⅝
# &frac78; => ⅞
# &sup1; => ¹
# &sup2; => ²
# &sup3; => ³
# &plus; => +
# &plusmn; => ±
# &equals; => =
# &divide; => ÷
# &times; => ×
# &curren; => ¤
# &num; => #
# &percnt; => %
# &ast; => ∗
# &commat; => @
# &bsol; => \
# &lcub; => {
# &horbar; => ―
# &verbar; => |
# &rcub; => }
# &micro; => µ
# &ohm; => Ω
# &deg; => °
# &ordm; => º
# &ordf; => ª
# &sect; => §
# &para; => ¶
# &middot; => ·
# &larr; => ←
# &rarr; => →
# &uarr; => ↑
# &darr; => ↓
# &copy; => ©
# &reg; => ®
# &trade; => ™
# &brvbar; => ¦
# &not; => ¬
# &sung; => ♩
# &excl; => !
# &iexcl; => ¡
# &quot; => "
# &apos; => '
# &lpar; => (
# &rpar; => )
# &comma; => ,
# &lowbar; => _
# &hyphen; => -
# &period; => .
# &sol; => /
# &colon; => :
# &semi; => ;
# &quest; => ?
# &iquest; => ¿
# &laquo; => «
# &raquo; => »
# &lsquo; => ‘
# &rsquo; => ’
# &ldquo; => “
# &rdquo; => ”
# &nbsp; =>
# &shy; => -
# &acute; => ´
# &breve; => ˘
# &caron; => ˇ
# &cedil; => ¸
# &circ; => ^
# &dblac; => ˝
# &die; => ¨
# &dot; => ˙
# &grave; => `
# &macr; => ¯
# &ogon; => ˛
# &ring; => ˚
# &tilde; => ˜
# &uml; => ¨
# &amacr; => ā
# &umacr; => ū
# &frac27; => ²⁄₇
# &frac37; => ³⁄₇
# &frac57; => ⁵⁄₇
# &cacute; => ć
# &Edot; => Ė
# &ucaron; => ˇ
# &frac25; => ⅖
# &frac44; => ⁴⁄₄
# &acaron; => ǎ
# &icaron; => ǐ
# &zdot; => ż
# &odblac; => ő
# &udblac; => ű
# &OElig; => Œ
# &cyrilNo; => №
# &cyrilE; => Э
# &cyrilel; => л
# &cyrilem; => м
# &cyrilen; => н
# &cyrilhard; => ъ
# &cyrilsoft; => ь
# &cyrilGHE; => Г
# &cyrilPE; => П
# &cyrilya; => я
# &cyrilzhe; => ж
# &cyrilka; => к
# &cyrilve; => в
# &schwa; => ə
# &Ccaron; => Č
# &abreve; => ă
# &Scaron; => Š
# &scedil; => ş
# &amp; => &
# &tcedil; => ţ
# &eogon; => ę
# &lstrok; => ł
# &nacute; => ń
# &ocaron; => ǒ
# &scaron; => š
# &sacute; => ś
# &utilde; => ũ
# &zacute; => ź
# &frac68; => ⁶⁄₈
# &ecaron; => ě
# &rcaron; => ř
# &vcaron; => vˇ
# &alphaacute; => ἁ
# &finalsigma; => ς
# &iota; => ι
# &ksi; => ξ
# &My; => Μ
# &my; => μ
# &omikron; => ο
# &metDash; => –
# &edot; => ė
# &corrMark; => ☥
# &nbar; => n̅
# &Okvist; => Ǫ
# &oelig; => œ
# &tu20; =>
# &frac24; => ²⁄₄
# &frac13; => ⅓
# &frac23; => ⅔
# &frac15; => ⅕
# &frac16; => ⅙
# &frac17; => ⅟₇
# &acuteCentre; => ´
# &foot; => '
# &rapo; => ’
# &lapo; => ‘
# &hellip; => …
# &omacr; => ō
# &bull; => •
# &titleColon; => :
# &lsaquo; => ‹
# &rsaquo; => ›
# &zcaron; => ž
# &Zcaron; => Ž
# &ccaron; => č
# &okvist; => ǫ
# &mark; => Ֆ
# &skilling; => ʄ
# &frac45; => ⅘
# &an; => ˈ
# &bue; => ∪
# &rep; => "
# &supn; => ⁿ
# &mbar; => m̅
# &amp;dash; => &
# &dash; => –
# &lquo; => «
# &rquo; => »
# %HIS_entiteter; =>
# ]&gt; => <
# &gt; => <
# &rapo; => '
# ]< =>
# &referenceMark; => ※
# &ergo; => ɔ

# %% [markdown]
# ## Slett tagger vi ikke vil ha

# %%
if tag_hisdel == 1:
    tags_to_erase.append("his:hisdel")
elif tag_hisdel == 2:
    print("Alle <his:hisdel>-tagger blir erstattet med markdown: { ~~ [innhold] ~~ }")
    print("Obs, dette fungerer ikke enda. :/")
    # for tag in content.findAll('his:hisdel'):
        # tag.replaceWith("~~ %s ~~" % a.string)
elif tag_hisdel == 0:
    if tag_overwritten == 1:
        tags_to_erase.append("overwritten") 
        # content.findAll("his:hisdel", {"rend" : "overwritten"})
    elif tag_overwritten == 2:
        print("TBI: markdown around overwrittens")
    if tag_overstrike == 1:
        tags_to_erase.append("overstrike") 
        # content.findAll("his:hisdel", {"rend" : "overstrike"})
    elif tag_overstrike == 2:
        print("TBI: markdown around overstrikes")
    if tag_diagonalOverstrike == 1:
        tags_to_erase.append("diagonalOverstrike")
        # content.findAll("his:hisdel", {"rend" : "diagonalOverstrike"})
    elif tag_overstrike == 2:
        print("TBI: markdown around diagonal overstrikes")

# %% [markdown]
# ## GLOB: *The yeast of thought and mind*
# Etablerer filstier, dvs at programmet finner kildefilene.

# %%
# GLOB GLOB GOBGALAB
import glob
paths = []
for path in glob.glob('xml_src/**/*.xml', recursive=True):
    paths.append(path)
#paths # Liste over stier til filer i SRC
errors = []
outputs = []
for path in paths:
    path = path.replace('xml_src','xml_output')
    outputs.append(path)
#outputs # Liste over stier til nye filer

# %% [markdown]
# ### Logg: filstier

# %%
i = 0
for path in paths:
    print(i,path)
    i+=1
# Out:
# 0 xml_src\brev\B1844-1871ht.xml
# 1 xml_src\brev\B1871-1879ht.xml
# 2 xml_src\brev\B1880-1889ht.xml
# 3 xml_src\brev\B1890-1905ht.xml
# 4 xml_src\dikt\BlaDigt8191.xml
# 5 xml_src\dikt\Di01.xml
# 6 xml_src\dikt\Di41110a.xml
# 7 xml_src\dikt\Di41113h.xml
# 8 xml_src\dikt\Di42622.xml
# 9 xml_src\dikt\Di71.xml
# 10 xml_src\dikt\Di75.xml
# 449 xml_src\drama\SS\SS41112f_1-2.xml
# 450 xml_src\drama\SS\SS41112f_9-10.xml
# 451 xml_src\drama\SS\SS41112_NBO.xml
# 452 xml_src\drama\SS\SS77.xml
# 453 xml_src\drama\SS\SS77a.xml
# 454 xml_src\drama\SS\SS81469_1-2.xml
# 455 xml_src\drama\SS\SS81469_3.xml
# 456 xml_src\drama\SS\SS81469_4-5.xml
# 457 xml_src\drama\SS\SS81469_NBO.xml
# 458 xml_src\drama\SS\SS81931.xml
# 459 xml_src\drama\SS\SS8956.xml
# 460 xml_src\drama\SS\SS93.xml
# 461 xml_src\drama\SS\SSFU.xml
# 462 xml_src\drama\SS\SSht.xml
# 463 xml_src\drama\SS\SSht_noter.xml
# 464 xml_src\drama\Sv\Sv4926.xml
# 465 xml_src\drama\Sv\Svht.xml
# 466 xml_src\drama\Sv\Svht_noter.xml
# 467 xml_src\drama\UF\UF41109a.xml
# 468 xml_src\drama\UF\UF41109b.xml
# 469 xml_src\drama\UF\UF4262.xml
# 470 xml_src\drama\UF\UF69.xml
# 471 xml_src\drama\UF\UF69a.xml
# 472 xml_src\drama\UF\UF74.xml
# 473 xml_src\drama\UF\UF80.xml
# 474 xml_src\drama\UF\UF81924.xml
# 475 xml_src\drama\UF\UF81937a.xml
# 476 xml_src\drama\UF\UF83.xml
# 477 xml_src\drama\UF\UF95.xml
# 478 xml_src\drama\UF\UFFU.xml
# 479 xml_src\drama\UF\UFht.xml
# 480 xml_src\drama\UF\UFht_noter.xml
# 481 xml_src\drama\Vi\Vi41115a.xml
# 482 xml_src\drama\Vi\Vi41115b.xml
# 483 xml_src\drama\Vi\Vi41115c.xml
# 484 xml_src\drama\Vi\Vi41674.xml
# 485 xml_src\drama\Vi\Vi4262III1.xml
# 486 xml_src\drama\Vi\Vi81944.xml
# 487 xml_src\drama\Vi\Vi84.xml
# 488 xml_src\drama\Vi\Vi84a.xml
# 489 xml_src\drama\Vi\ViFU.xml
# 490 xml_src\drama\Vi\Viht.xml
# 491 xml_src\drama\Vi\Viht_noter.xml
# 492 xml_src\sakprosa\P1841-1905ht.xml

# %% [markdown]
# ## Programkjerne
# Det er her det skjer.

# %%
# ACTION
i = 0
x = 0
y = 0
for thing in paths: # For hver sti (med endestasjon fil) i listen over stier
    print(i+1,thing)
    # Filhåndtering I - Les og last xml-filer inn i minne
    with open(thing, "r", encoding="utf-8") as file: # Åpne stien, les, med encoding UTF8
        # Read each line in the file, readlines() returns a list of lines
        content = file.readlines()
        # Combine the lines in the list into a string
        content = "".join(content) # Variabel content får innholdet
    
    # Filhåndtering II - Lag ny sti
    frags = outputs[i].split('\\') # Splitt outputstrengen for sti
    if "xml" in frags[2]: # Hvis filen er 3 ned, altså vi finner xml-filen her (eks. xml_src\dikt\~.xml)
        dirName = frags[0]+"\\"+frags[1] # Dirname blir 2 dyp (xml_output\DIRNAME\)
        metaName = frags[2] # Trenger et navn på filen
    else: # OBS!! OBS!! Hvis filen IKKE er 3 ned ANTAR vi at den er 4 ned, slik som de(n) er i dramafolderen.
        metaName = frags[3] # Navn på filen
        dirName = frags[0]+"\\"+frags[1]+"\\"+frags[2] # Dirname blir 3 dyp (xml_output\drama\DIRNAME\)
        archDir = frags[0]+"\\"+frags[1] # FAILSAFE for DRAMA: Drama er ett hakk lengre ned i hierarkiet enn alt annet. Skap mappe for å ta drama
        #OBS - koden her ANTAR at senteret ALLTID følger samme praksis. Koden må endres om praksis endres.
        if not os.path.exists(archDir): # Hvis subfolder ikke finnes (eks.\drama\BE\)
            os.mkdir(archDir) # Skap den

    metaFolder = dirName+"\\metadata" # Vi forbereder en metadatafolder ett steg under stien vi lagde over
    metaName = metaName[:-4] # Strip . x m l. Bruker ikke outputs[i] fordi den gir hele stien, metaName er fragment
    metaFile = metaFolder+"\\"+metaName+"_METADATA.txt" # Metadatafilen skal få samme filnavn med _metadata-suffiks
    outputs[i] = outputs[i][:-4] # Strip 4 tegn fra slutten av hver streng for å få bort .xml (4. 3X 2M 1L)
    # Create target Directory if don't exist
    if not os.path.exists(dirName): # Hvis folderen ikke eksisterer
        os.mkdir(dirName) # Lag folderen
        os.mkdir(metaFolder) # Legg metadata-folder inne i den igjen
    name = outputs[i]+filsuffiks+filformat # Outputfil får navnet X_SANERT.txt
    # XML til TXT - Det er her vi skal sette inn X FOR EACH for å redigere XML-filene.
    
    content = BeautifulSoup(content, from_encoding="UTF-8") # Content er content som bs4-objekt...
    
    # Hent strukturer vi skal beholde
    try:
        titlestatement = content.find("titlestmt") # Finn title statement
        titlestatement.extract() # Hent (og fjern) title statement-delen
    except:
        print("> Ingen title statement.")

    try:
        filedescription = content.find("filedesc") # Finn filbeskrivelsen
        filedescription.extract() # Hent (og fjern) filbeskrivelsen
    except:
        print("> Ingen filbeskrivelse.")
    try:
        castlist = content.find("his:hiscastlist") # Finn rollelisten
        castlist.extract() # Hent (og fjern) rollelisten
        print("Hentet rollelisten")
        checkList = 1
    except:
        print("> Ingen rolleliste.")
        checkList = 0
        
    if checkList == 1: # Kan gjøre try, men...
        target = content.body # Mål: Body-taggen
        castlist.append(" ") # Legg til et mellomrom helt på slutten for sikkerhets skyld.
        target.insert_before(castlist) # Sett inn castlist foran target
        #target = content.front # Mål (<front>)
        #target.replace_with(castlist) # ERSTATT målet med castlist-taggen
        
    # Slett tagger vi ikke skal beholde
    if tag_hisdel == 2:
        z = 0
        try:
            for tag in content.findAll('his:hisdel'):
                tag.replaceWith(" ~~ %s ~~ " % a.string)
                z += 1
            if z > 0:
                print(">Erstattet",z,"hisdel-tagger med markdown-tagger.")
            else:
                print(">his:hisdel-tagger er ikke 0, men 0 ble fjernet...? Hva.")
        except:
            print("> Ingen hisdel-tagger å endre.")
            
            
    try: # Her er kode for å endre & bevare replikker
        speaker = content.findAll('speaker') # Finn alle replikker
        for talker in speaker: # For hver av disse
            tag = content.new_tag("dummytag") # Lag en ny, tom tagg
            tag.string = (talker.string) # Inkonsekvent punktum- og mellomromsføring fører til at vi ikke kan legge ->
                                        # mellomrom eller punktum etter denne.
            talker.insert_before(tag) # Sett elementet inn før replikken
            talker.decompose() # Ødelegg kildeelementet for å hindre dobbelt opp
        print("> Fikset replikker.")
    except:
        print("> Fant ingen replikker.")
    try:
        for tag in tags_to_erase: # For hver tagg
            to_remove = content.find_all(tag) # Finn alle instanser av taggen
            for remove in to_remove: # For hver av disse
                remove.decompose() # Fjern taggen og innholdet helt
        print("> Fjernet uønskede tagger.")
    except:
        print("> Fant ingen uønskede tagger.")
    content = str(content) # CONTENT ER NÅ STRING - STRINGMETODER FUNGERER, BS4-METODER FUNGERER IKKE
    z = 0 # Tell fra 0 i z
    for code in codes: # For hver kode
        if code in content: # Hvis koden finnes i teksten
            content = content.replace(code,asciis[z]) # Erstatt koden med ascii
            #print('Erstattet',code,'med',asciis[z]) # Print bekreftelse
        z+=1 # Neste kode/ascii etter å ha sjekket hver kode
    print("> Erstattet feltkoder med ASCII.")
    
    content = re.sub('<[^<]+>', "", content) # Slett alle resterende tagger UTEN å røre innholdet
    content = re.sub('\s+',' ', content) # Korriger alle instanser av multimellomrom til enkeltmellomrom
    content = content.replace("&typHyp; ","")
    content = content.replace("&typHyp;","")
    #if replacemode == "ordinary":
    content = content.replace("\n"," ") # Slett newline og erstatt med mellomrom 
    content = content.replace("'“'","")
    content = content.replace("&dash;","-")
    content = content.replace("&"," & ")
    content = content.replace("& &"," & ")
    content = content.replace(". &",".")
    #content = content.replace(" > ","")
    content = content.replace("'\"'", "")
    content = content.replace(" < ","")
        #content = content.replace("&typHyp;","") # Slett disse etterpå.
    #elif replacemode == "regex": # Ikke bruk denne tror jeg egentlig
    #    content = content.replace("\n"," ")
    #    content = re.sub("'“'", "", content) # Korriger enkelte instanser av '“'
    #    content = re.sub("'\"'", "", content) # Korriger enkelte instanser av '"'...
    #    content = re.sub("&dash;","–",content) # Korriger &dash; fordi den ikke vil korrigeres gjennom translation.csv??
    #    content = re.sub("&", " & ", content) # Her finner vi alle ampersander og legger mellomrom rundt. Disse slettes etterpå.
    #    content = re.sub('\s+',' ', content) # Korriger alle instanser av multimellomrom til enkeltmellomrom
    #    content = re.sub("& &", "&", content) # Korriger dobbeltampersander etter mellomrom er fjernet.
    #    content = re.sub(". &", ".", content) # Starter da ikke en setning med ampersand-tegn, vel...?
    #    content = re.sub(" < ","",content) # Fjerner " < " fra starten av dokumentet og/eller andre steder.
    content = re.sub('\s+',' ', content) # Korriger alle instanser av multimellomrom til enkeltmellomrom IGJEN.
    # For sikkerhets skyld.
    
    if tag_hisdel == 1: # Hvis vi sletter hisdel-taggen med innhold
        #content = re.sub(" . ", " ", content) # NEI!
        content = content.replace(" . ", " ") # JA!
        content = content.replace(" < ", "") # JA!
    print("> Formatert.")
    # Filhåndtering III - Skriv til disk
    try: # Prøv å skrive til disk
        f = open(name, "w", encoding="utf-8") # Ikke glem encoding="utf-8", sånn som jeg gjorde.
        f.write(content) # Skriv innholdet i content-variabelen
        f.close()
        print(">> Opprettet",name,"i",dirName)
        x+=1
    except: # Hvis vi møter på feil, rapporter kilden
        print("XXX FILFEIL!",thing)
        f = open(name+"_ERROR", "w", encoding="utf-8")
        f.write("XXX Filfeil!")
        f.close()
        errors.append(name)
        y+=1
    metadata = str(filedescription)+str(titlestatement)
    try: # Prøv å skrive metadata! til disk
        f = open(metaFile, "w", encoding="utf-8") # Ikke glem encoding="utf-8", sånn som jeg gjorde.
        f.write(metadata) # Skriv innholdet i metadata-variabelen
        f.close()
        print(">> Metadata opprettet:",metaFile)
        x+=1
    except: # Hvis vi møter på feil, rapporter kilden
        print("YYY FILFEIL!",thing)
        f = open(metaFile+"_ERROR", "w", encoding="utf-8")
        f.write("YYY Metadata filfeil!")
        f.close()
        errors.append(name)
        y+=1
    i+=1
    #if i > 70:
    #    raise KeyboardInterrupt
    print("\n")
print("\nLog:",x,"files parsed to text.",y,"files failing to parse.")
if y > 0:
    face = ":("
else:
    face = ":)"
# Out:
# 1 xml_src\brev\B1844-1871ht.xml
# C:\Users\lokes\Anaconda3\lib\site-packages\bs4\__init__.py:221: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\brev\B1844-1871ht_SANERT.txt i xml_output\brev
# >> Metadata opprettet: xml_output\brev\metadata\B1844-1871ht_METADATA.txt
#
#
# 2 xml_src\brev\B1871-1879ht.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\brev\B1871-1879ht_SANERT.txt i xml_output\brev
# >> Metadata opprettet: xml_output\brev\metadata\B1871-1879ht_METADATA.txt
#
#
# 3 xml_src\brev\B1880-1889ht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\brev\B1880-1889ht_SANERT.txt i xml_output\brev
# >> Metadata opprettet: xml_output\brev\metadata\B1880-1889ht_METADATA.txt
#
#
# 4 xml_src\brev\B1890-1905ht.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\brev\B1890-1905ht_SANERT.txt i xml_output\brev
# >> Metadata opprettet: xml_output\brev\metadata\B1890-1905ht_METADATA.txt
#
#
# 5 xml_src\dikt\BlaDigt8191.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\BlaDigt8191_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\BlaDigt8191_METADATA.txt
#
#
# 6 xml_src\dikt\Di01.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di01_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di01_METADATA.txt
#
#
# 7 xml_src\dikt\Di41110a.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di41110a_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di41110a_METADATA.txt
#
#
# 8 xml_src\dikt\Di41113h.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di41113h_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di41113h_METADATA.txt
#
#
# 9 xml_src\dikt\Di42622.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di42622_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di42622_METADATA.txt
#
#
# 10 xml_src\dikt\Di71.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di71_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di71_METADATA.txt
#
#
# 11 xml_src\dikt\Di75.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di75_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di75_METADATA.txt
#
#
# 12 xml_src\dikt\Di79.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di79_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di79_METADATA.txt
#
#
# 13 xml_src\dikt\Di81928.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di81928_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di81928_METADATA.txt
#
#
# 14 xml_src\dikt\Di82.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di82_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di82_METADATA.txt
#
#
# 15 xml_src\dikt\Di86.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di86_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di86_METADATA.txt
#
#
# 16 xml_src\dikt\Di91.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di91_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di91_METADATA.txt
#
#
# 17 xml_src\dikt\Di96.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Di96_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Di96_METADATA.txt
#
#
# 18 xml_src\dikt\DiFU.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\DiFU_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\DiFU_METADATA.txt
#
#
# 19 xml_src\dikt\Diktht.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\dikt\Diktht_SANERT.txt i xml_output\dikt
# >> Metadata opprettet: xml_output\dikt\metadata\Diktht_METADATA.txt
#
#
# 20 xml_src\drama\BE\BE428691_KBK.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BE428691_KBK_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BE428691_KBK_METADATA.txt
#
#
# 21 xml_src\drama\BE\BE428691_KBK_gml.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BE428691_KBK_gml_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BE428691_KBK_gml_METADATA.txt
#
#
# 22 xml_src\drama\BE\BE428691_KBK_original.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BE428691_KBK_original_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BE428691_KBK_original_METADATA.txt
#
#
# 23 xml_src\drama\BE\BEht.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BEht_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BEht_METADATA.txt
#
#
# 24 xml_src\drama\BE\BEht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BEht_noter_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BEht_noter_METADATA.txt
#
#
# 25 xml_src\drama\BE\BEht_original.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BEht_original_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BEht_original_METADATA.txt
#
#
# 26 xml_src\drama\BE\BEht_ut.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BE\BEht_ut_SANERT.txt i xml_output\drama\BE
# >> Metadata opprettet: xml_output\drama\BE\metadata\BEht_ut_METADATA.txt
#
#
# 27 xml_src\drama\Br\Br03.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br03_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br03_METADATA.txt
#
#
# 28 xml_src\drama\Br\Br05.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br05_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br05_METADATA.txt
#
#
# 29 xml_src\drama\Br\Br4262I11.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br4262I11_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br4262I11_METADATA.txt
#
#
# 30 xml_src\drama\Br\Br4262I12.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br4262I12_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br4262I12_METADATA.txt
#
#
# 31 xml_src\drama\Br\Br66.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br66_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br66_METADATA.txt
#
#
# 32 xml_src\drama\Br\Br66a.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br66a_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br66a_METADATA.txt
#
#
# 33 xml_src\drama\Br\Br66b.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br66b_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br66b_METADATA.txt
#
#
# 34 xml_src\drama\Br\Br66c.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br66c_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br66c_METADATA.txt
#
#
# 35 xml_src\drama\Br\Br68.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br68_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br68_METADATA.txt
#
#
# 36 xml_src\drama\Br\Br71.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br71_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br71_METADATA.txt
#
#
# 37 xml_src\drama\Br\Br74.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br74_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br74_METADATA.txt
#
#
# 38 xml_src\drama\Br\Br76.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br76_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br76_METADATA.txt
#
#
# 39 xml_src\drama\Br\Br81.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br81_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br81_METADATA.txt
#
#
# 40 xml_src\drama\Br\Br81925.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br81925_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br81925_METADATA.txt
#
#
# 41 xml_src\drama\Br\Br85.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br85_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br85_METADATA.txt
#
#
# 42 xml_src\drama\Br\Br89.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br89_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br89_METADATA.txt
#
#
# 43 xml_src\drama\Br\Br92.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br92_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br92_METADATA.txt
#
#
# 44 xml_src\drama\Br\Br95.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br95_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br95_METADATA.txt
#
#
# 45 xml_src\drama\Br\Br98.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Br98_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Br98_METADATA.txt
#
#
# 46 xml_src\drama\Br\BrFU.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\BrFU_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\BrFU_METADATA.txt
#
#
# 47 xml_src\drama\Br\Brht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Brht_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Brht_METADATA.txt
#
#
# 48 xml_src\drama\Br\Brht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Br\Brht_noter_SANERT.txt i xml_output\drama\Br
# >> Metadata opprettet: xml_output\drama\Br\metadata\Brht_noter_METADATA.txt
#
#
# 49 xml_src\drama\BS\BS01.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BS01_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BS01_METADATA.txt
#
#
# 50 xml_src\drama\BS\BS41117b.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BS41117b_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BS41117b_METADATA.txt
#
#
# 51 xml_src\drama\BS\BS41292.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BS41292_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BS41292_METADATA.txt
#
#
# 52 xml_src\drama\BS\BS4262IV1.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BS4262IV1_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BS4262IV1_METADATA.txt
#
#
# 53 xml_src\drama\BS\BS92.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BS92_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BS92_METADATA.txt
#
#
# 54 xml_src\drama\BS\BSFU.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BSFU_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BSFU_METADATA.txt
#
#
# 55 xml_src\drama\BS\BSht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BSht_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BSht_METADATA.txt
#
#
# 56 xml_src\drama\BS\BSht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BSht_noter_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BSht_noter_METADATA.txt
#
#
# 57 xml_src\drama\BS\BSLondon.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\BS\BSLondon_SANERT.txt i xml_output\drama\BS
# >> Metadata opprettet: xml_output\drama\BS\metadata\BSLondon_METADATA.txt
#
#
# 58 xml_src\drama\C1\C14936_1-17_19-47.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C14936_1-17_19-47_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C14936_1-17_19-47_METADATA.txt
#
#
# 59 xml_src\drama\C1\C14936_18r.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C14936_18r_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C14936_18r_METADATA.txt
#
#
# 60 xml_src\drama\C1\C14936_18v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C14936_18v_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C14936_18v_METADATA.txt
#
#
# 61 xml_src\drama\C1\C14936_NBO.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C14936_NBO_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C14936_NBO_METADATA.txt
#
#
# 62 xml_src\drama\C1\C14936_NBOgammel.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C14936_NBOgammel_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C14936_NBOgammel_METADATA.txt
#
#
# 63 xml_src\drama\C1\C150.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C150_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C150_METADATA.txt
#
#
# 64 xml_src\drama\C1\C1ht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C1ht_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C1ht_METADATA.txt
#
#
# 65 xml_src\drama\C1\C1ht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C1ht_noter_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C1ht_noter_METADATA.txt
#
#
# 66 xml_src\drama\C1\C1_forord.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C1\C1_forord_SANERT.txt i xml_output\drama\C1
# >> Metadata opprettet: xml_output\drama\C1\metadata\C1_forord_METADATA.txt
#
#
# 67 xml_src\drama\C2\C241395.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C241395_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C241395_METADATA.txt
#
#
# 68 xml_src\drama\C2\C275.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C275_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C275_METADATA.txt
#
#
# 69 xml_src\drama\C2\C2819381.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C2819381_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C2819381_METADATA.txt
#
#
# 70 xml_src\drama\C2\C2819382.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C2819382_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C2819382_METADATA.txt
#
#
# 71 xml_src\drama\C2\C291.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C291_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C291_METADATA.txt
#
#
# 72 xml_src\drama\C2\C2FU.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C2FU_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C2FU_METADATA.txt
#
#
# 73 xml_src\drama\C2\C2ht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C2ht_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C2ht_METADATA.txt
#
#
# 74 xml_src\drama\C2\C2ht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\C2\C2ht_noter_SANERT.txt i xml_output\drama\C2
# >> Metadata opprettet: xml_output\drama\C2\metadata\C2ht_noter_METADATA.txt
#
#
# 75 xml_src\drama\Du\Du01.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du01_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du01_METADATA.txt
#
#
# 76 xml_src\drama\Du\Du200.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du200_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du200_METADATA.txt
#
#
# 77 xml_src\drama\Du\Du39.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du39_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du39_METADATA.txt
#
#
# 78 xml_src\drama\Du\Du41113a-f_NBO.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113a-f_NBO_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113a-f_NBO_METADATA.txt
#
#
# 79 xml_src\drama\Du\Du41113a_1r_1v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113a_1r_1v_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113a_1r_1v_METADATA.txt
#
#
# 80 xml_src\drama\Du\Du41113a_2r_3v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113a_2r_3v_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113a_2r_3v_METADATA.txt
#
#
# 81 xml_src\drama\Du\Du41113a_4v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113a_4v_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113a_4v_METADATA.txt
#
#
# 82 xml_src\drama\Du\Du41113b.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113b_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113b_METADATA.txt
#
#
# 83 xml_src\drama\Du\Du41113c.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113c_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113c_METADATA.txt
#
#
# 84 xml_src\drama\Du\Du41113d.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113d_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113d_METADATA.txt
#
#
# 85 xml_src\drama\Du\Du41113e.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113e_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113e_METADATA.txt
#
#
# 86 xml_src\drama\Du\Du41113f.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113f_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113f_METADATA.txt
#
#
# 87 xml_src\drama\Du\Du41113h.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113h_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113h_METADATA.txt
#
#
# 88 xml_src\drama\Du\Du41113i.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du41113i_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du41113i_METADATA.txt
#
#
# 89 xml_src\drama\Du\Du79.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du79_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du79_METADATA.txt
#
#
# 90 xml_src\drama\Du\Du80a.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du80a_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du80a_METADATA.txt
#
#
# 91 xml_src\drama\Du\Du80b.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du80b_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du80b_METADATA.txt
#
#
# 92 xml_src\drama\Du\Du8952.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du8952_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du8952_METADATA.txt
#
#
# 93 xml_src\drama\Du\Du96.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Du96_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Du96_METADATA.txt
#
#
# 94 xml_src\drama\Du\DuFU.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\DuFU_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\DuFU_METADATA.txt
#
#
# 95 xml_src\drama\Du\Duht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Duht_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Duht_METADATA.txt
#
#
# 96 xml_src\drama\Du\Duhtw.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Duhtw_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Duhtw_METADATA.txt
#
#
# 97 xml_src\drama\Du\Duhtw_ny.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Duhtw_ny_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Duhtw_ny_METADATA.txt
#
#
# 98 xml_src\drama\Du\Duht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Du\Duht_noter_SANERT.txt i xml_output\drama\Du
# >> Metadata opprettet: xml_output\drama\Du\metadata\Duht_noter_METADATA.txt
#
#
# 99 xml_src\drama\F1\F1280r_BJELKE.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_BJELKE_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_BJELKE_METADATA.txt
#
#
# 100 xml_src\drama\F1\F1280r_BJORN.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_BJORN_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_BJORN_METADATA.txt
#
#
# 101 xml_src\drama\F1\F1280r_EINAR.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_EINAR_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_EINAR_METADATA.txt
#
#
# 102 xml_src\drama\F1\F1280r_ELINE.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_ELINE_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_ELINE_METADATA.txt
#
#
# 103 xml_src\drama\F1\F1280r_FINN.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_FINN_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_FINN_METADATA.txt
#
#
# 104 xml_src\drama\F1\F1280r_FRUINGER.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_FRUINGER_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_FRUINGER_METADATA.txt
#
#
# 105 xml_src\drama\F1\F1280r_NIELSLYKKE.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_NIELSLYKKE_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_NIELSLYKKE_METADATA.txt
#
#
# 106 xml_src\drama\F1\F1280r_SKAKTAVL.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_SKAKTAVL_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_SKAKTAVL_METADATA.txt
#
#
# 107 xml_src\drama\F1\F1280r_SOLDAT.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_SOLDAT_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_SOLDAT_METADATA.txt
#
#
# 108 xml_src\drama\F1\F1280r_STEENSSON.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280r_STEENSSON_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280r_STEENSSON_METADATA.txt
#
#
# 109 xml_src\drama\F1\F1280s.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1280s_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1280s_METADATA.txt
#
#
# 110 xml_src\drama\F1\F157.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F157_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F157_METADATA.txt
#
#
# 111 xml_src\drama\F1\F1ht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1ht_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1ht_METADATA.txt
#
#
# 112 xml_src\drama\F1\F1ht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1ht_noter_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1ht_noter_METADATA.txt
#
#
# 113 xml_src\drama\F1\F1ht_original.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1ht_original_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1ht_original_METADATA.txt
#
#
# 114 xml_src\drama\F1\F1ht_ut.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1ht_ut_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1ht_ut_METADATA.txt
#
#
# 115 xml_src\drama\F1\F1S.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F1\F1S_SANERT.txt i xml_output\drama\F1
# >> Metadata opprettet: xml_output\drama\F1\metadata\F1S_METADATA.txt
#
#
# 116 xml_src\drama\F2\F274.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F274_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F274_METADATA.txt
#
#
# 117 xml_src\drama\F2\F281939.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F281939_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F281939_METADATA.txt
#
#
# 118 xml_src\drama\F2\F28950.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F28950_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F28950_METADATA.txt
#
#
# 119 xml_src\drama\F2\F291.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F291_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F291_METADATA.txt
#
#
# 120 xml_src\drama\F2\F298.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F298_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F298_METADATA.txt
#
#
# 121 xml_src\drama\F2\F2FU.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F2FU_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F2FU_METADATA.txt
#
#
# 122 xml_src\drama\F2\F2ht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F2ht_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F2ht_METADATA.txt
#
#
# 123 xml_src\drama\F2\F2ht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\F2\F2ht_noter_SANERT.txt i xml_output\drama\F2
# >> Metadata opprettet: xml_output\drama\F2\metadata\F2ht_noter_METADATA.txt
#
#
# 124 xml_src\drama\FH\FH02.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH02_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH02_METADATA.txt
#
#
# 125 xml_src\drama\FH\FH166.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH166_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH166_METADATA.txt
#
#
# 126 xml_src\drama\FH\FH41116a_1-2_4_3.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_1-2_4_3_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_1-2_4_3_METADATA.txt
#
#
# 127 xml_src\drama\FH\FH41116a_11r.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_11r_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_11r_METADATA.txt
#
#
# 128 xml_src\drama\FH\FH41116a_11v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_11v_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_11v_METADATA.txt
#
#
# 129 xml_src\drama\FH\FH41116a_3_7-8.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_3_7-8_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_3_7-8_METADATA.txt
#
#
# 130 xml_src\drama\FH\FH41116a_5r_6v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_5r_6v_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_5r_6v_METADATA.txt
#
#
# 131 xml_src\drama\FH\FH41116a_5v.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_5v_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_5v_METADATA.txt
#
#
# 132 xml_src\drama\FH\FH41116a_6r.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_6r_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_6r_METADATA.txt
#
#
# 133 xml_src\drama\FH\FH41116a_9r.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_9r_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_9r_METADATA.txt
#
#
# 134 xml_src\drama\FH\FH41116a_9v-10_12-15.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116a_9v-10_12-15_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116a_9v-10_12-15_METADATA.txt
#
#
# 135 xml_src\drama\FH\FH41116b.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116b_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116b_METADATA.txt
#
#
# 136 xml_src\drama\FH\FH41116b_I.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116b_I_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116b_I_METADATA.txt
#
#
# 137 xml_src\drama\FH\FH41116b_orig.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116b_orig_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116b_orig_METADATA.txt
#
#
# 138 xml_src\drama\FH\FH41116_NBO.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116_NBO_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116_NBO_METADATA.txt
#
#
# 139 xml_src\drama\FH\FH41116_NBO_orig.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH41116_NBO_orig_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH41116_NBO_orig_METADATA.txt
#
#
# 140 xml_src\drama\FH\FH4262III3.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH4262III3_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH4262III3_METADATA.txt
#
#
# 141 xml_src\drama\FH\FH4262III3_orig.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH4262III3_orig_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH4262III3_orig_METADATA.txt
#
#
# 142 xml_src\drama\FH\FH88.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FH88_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FH88_METADATA.txt
#
#
# 143 xml_src\drama\FH\FHFU.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FHFU_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FHFU_METADATA.txt
#
#
# 144 xml_src\drama\FH\FHht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FHht_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FHht_METADATA.txt
#
#
# 145 xml_src\drama\FH\FHht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\FH\FHht_noter_SANERT.txt i xml_output\drama\FH
# >> Metadata opprettet: xml_output\drama\FH\metadata\FHht_noter_METADATA.txt
#
#
# 146 xml_src\drama\Fj\Fj4504.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fj\Fj4504_SANERT.txt i xml_output\drama\Fj
# >> Metadata opprettet: xml_output\drama\Fj\metadata\Fj4504_METADATA.txt
#
#
# 147 xml_src\drama\Fj\Fj4935.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fj\Fj4935_SANERT.txt i xml_output\drama\Fj
# >> Metadata opprettet: xml_output\drama\Fj\metadata\Fj4935_METADATA.txt
#
#
# 148 xml_src\drama\Fj\Fjht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fj\Fjht_SANERT.txt i xml_output\drama\Fj
# >> Metadata opprettet: xml_output\drama\Fj\metadata\Fjht_METADATA.txt
#
#
# 149 xml_src\drama\Fj\Fjht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fj\Fjht_noter_SANERT.txt i xml_output\drama\Fj
# >> Metadata opprettet: xml_output\drama\Fj\metadata\Fjht_noter_METADATA.txt
#
#
# 150 xml_src\drama\Fj\Fjht_orig.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fj\Fjht_orig_SANERT.txt i xml_output\drama\Fj
# >> Metadata opprettet: xml_output\drama\Fj\metadata\Fjht_orig_METADATA.txt
#
#
# 151 xml_src\drama\Fj\Fjht_orig_ny.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fj\Fjht_orig_ny_SANERT.txt i xml_output\drama\Fj
# >> Metadata opprettet: xml_output\drama\Fj\metadata\Fjht_orig_ny_METADATA.txt
#
#
# 152 xml_src\drama\Fo\Fo82.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fo\Fo82_SANERT.txt i xml_output\drama\Fo
# >> Metadata opprettet: xml_output\drama\Fo\metadata\Fo82_METADATA.txt
#
#
# 153 xml_src\drama\Fo\Fo8954.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fo\Fo8954_SANERT.txt i xml_output\drama\Fo
# >> Metadata opprettet: xml_output\drama\Fo\metadata\Fo8954_METADATA.txt
#
#
# 154 xml_src\drama\Fo\Fo97.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fo\Fo97_SANERT.txt i xml_output\drama\Fo
# >> Metadata opprettet: xml_output\drama\Fo\metadata\Fo97_METADATA.txt
#
#
# 155 xml_src\drama\Fo\FoFU.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fo\FoFU_SANERT.txt i xml_output\drama\Fo
# >> Metadata opprettet: xml_output\drama\Fo\metadata\FoFU_METADATA.txt
#
#
# 156 xml_src\drama\Fo\Foht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fo\Foht_SANERT.txt i xml_output\drama\Fo
# >> Metadata opprettet: xml_output\drama\Fo\metadata\Foht_METADATA.txt
#
#
# 157 xml_src\drama\Fo\Foht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Fo\Foht_noter_SANERT.txt i xml_output\drama\Fo
# >> Metadata opprettet: xml_output\drama\Fo\metadata\Foht_noter_METADATA.txt
#
#
# 158 xml_src\drama\G1\G1348r_AndenMand.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\G1\G1348r_AndenMand_SANERT.txt i xml_output\drama\G1
# >> Metadata opprettet: xml_output\drama\G1\metadata\G1348r_AndenMand_METADATA.txt
#
#
# 159 xml_src\drama\G1\G1348r_Bengt.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\G1\G1348r_Bengt_SANERT.txt i xml_output\drama\G1
# >> Metadata opprettet: xml_output\drama\G1\metadata\G1348r_Bengt_METADATA.txt
#
#
# 160 xml_src\drama\G1\G1348r_GammelMand.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\G1\G1348r_GammelMand_SANERT.txt i xml_output\drama\G1
# >> Metadata opprettet: xml_output\drama\G1\metadata\G1348r_GammelMand_METADATA.txt
#
#
# 161 xml_src\drama\G1\G1348r_GjesterEn.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# ...
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS200_METADATA.txt
#
#
# 441 xml_src\drama\SS\SS41112a_19-20r.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112a_19-20r_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112a_19-20r_METADATA.txt
#
#
# 442 xml_src\drama\SS\SS41112a_20v.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112a_20v_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112a_20v_METADATA.txt
#
#
# 443 xml_src\drama\SS\SS41112a_21-22.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112a_21-22_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112a_21-22_METADATA.txt
#
#
# 444 xml_src\drama\SS\SS41112a_23-24.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112a_23-24_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112a_23-24_METADATA.txt
#
#
# 445 xml_src\drama\SS\SS41112a_25-26.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112a_25-26_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112a_25-26_METADATA.txt
#
#
# 446 xml_src\drama\SS\SS41112b.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112b_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112b_METADATA.txt
#
#
# 447 xml_src\drama\SS\SS41112c.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112c_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112c_METADATA.txt
#
#
# 448 xml_src\drama\SS\SS41112d.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112d_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112d_METADATA.txt
#
#
# 449 xml_src\drama\SS\SS41112e.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112e_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112e_METADATA.txt
#
#
# 450 xml_src\drama\SS\SS41112f_1-2.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112f_1-2_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112f_1-2_METADATA.txt
#
#
# 451 xml_src\drama\SS\SS41112f_9-10.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112f_9-10_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112f_9-10_METADATA.txt
#
#
# 452 xml_src\drama\SS\SS41112_NBO.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS41112_NBO_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS41112_NBO_METADATA.txt
#
#
# 453 xml_src\drama\SS\SS77.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS77_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS77_METADATA.txt
#
#
# 454 xml_src\drama\SS\SS77a.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS77a_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS77a_METADATA.txt
#
#
# 455 xml_src\drama\SS\SS81469_1-2.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS81469_1-2_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS81469_1-2_METADATA.txt
#
#
# 456 xml_src\drama\SS\SS81469_3.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS81469_3_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS81469_3_METADATA.txt
#
#
# 457 xml_src\drama\SS\SS81469_4-5.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS81469_4-5_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS81469_4-5_METADATA.txt
#
#
# 458 xml_src\drama\SS\SS81469_NBO.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS81469_NBO_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS81469_NBO_METADATA.txt
#
#
# 459 xml_src\drama\SS\SS81931.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS81931_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS81931_METADATA.txt
#
#
# 460 xml_src\drama\SS\SS8956.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS8956_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS8956_METADATA.txt
#
#
# 461 xml_src\drama\SS\SS93.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SS93_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SS93_METADATA.txt
#
#
# 462 xml_src\drama\SS\SSFU.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SSFU_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SSFU_METADATA.txt
#
#
# 463 xml_src\drama\SS\SSht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SSht_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SSht_METADATA.txt
#
#
# 464 xml_src\drama\SS\SSht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\SS\SSht_noter_SANERT.txt i xml_output\drama\SS
# >> Metadata opprettet: xml_output\drama\SS\metadata\SSht_noter_METADATA.txt
#
#
# 465 xml_src\drama\Sv\Sv4926.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Sv\Sv4926_SANERT.txt i xml_output\drama\Sv
# >> Metadata opprettet: xml_output\drama\Sv\metadata\Sv4926_METADATA.txt
#
#
# 466 xml_src\drama\Sv\Svht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Sv\Svht_SANERT.txt i xml_output\drama\Sv
# >> Metadata opprettet: xml_output\drama\Sv\metadata\Svht_METADATA.txt
#
#
# 467 xml_src\drama\Sv\Svht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Sv\Svht_noter_SANERT.txt i xml_output\drama\Sv
# >> Metadata opprettet: xml_output\drama\Sv\metadata\Svht_noter_METADATA.txt
#
#
# 468 xml_src\drama\UF\UF41109a.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF41109a_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF41109a_METADATA.txt
#
#
# 469 xml_src\drama\UF\UF41109b.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF41109b_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF41109b_METADATA.txt
#
#
# 470 xml_src\drama\UF\UF4262.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF4262_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF4262_METADATA.txt
#
#
# 471 xml_src\drama\UF\UF69.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF69_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF69_METADATA.txt
#
#
# 472 xml_src\drama\UF\UF69a.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF69a_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF69a_METADATA.txt
#
#
# 473 xml_src\drama\UF\UF74.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF74_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF74_METADATA.txt
#
#
# 474 xml_src\drama\UF\UF80.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF80_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF80_METADATA.txt
#
#
# 475 xml_src\drama\UF\UF81924.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF81924_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF81924_METADATA.txt
#
#
# 476 xml_src\drama\UF\UF81937a.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF81937a_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF81937a_METADATA.txt
#
#
# 477 xml_src\drama\UF\UF83.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF83_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF83_METADATA.txt
#
#
# 478 xml_src\drama\UF\UF95.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UF95_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UF95_METADATA.txt
#
#
# 479 xml_src\drama\UF\UFFU.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UFFU_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UFFU_METADATA.txt
#
#
# 480 xml_src\drama\UF\UFht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UFht_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UFht_METADATA.txt
#
#
# 481 xml_src\drama\UF\UFht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\UF\UFht_noter_SANERT.txt i xml_output\drama\UF
# >> Metadata opprettet: xml_output\drama\UF\metadata\UFht_noter_METADATA.txt
#
#
# 482 xml_src\drama\Vi\Vi41115a.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi41115a_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi41115a_METADATA.txt
#
#
# 483 xml_src\drama\Vi\Vi41115b.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi41115b_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi41115b_METADATA.txt
#
#
# 484 xml_src\drama\Vi\Vi41115c.xml
# > Ingen rolleliste.
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi41115c_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi41115c_METADATA.txt
#
#
# 485 xml_src\drama\Vi\Vi41674.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi41674_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi41674_METADATA.txt
#
#
# 486 xml_src\drama\Vi\Vi4262III1.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi4262III1_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi4262III1_METADATA.txt
#
#
# 487 xml_src\drama\Vi\Vi81944.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi81944_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi81944_METADATA.txt
#
#
# 488 xml_src\drama\Vi\Vi84.xml
# Hentet rollelisten
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi84_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi84_METADATA.txt
#
#
# 489 xml_src\drama\Vi\Vi84a.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Vi84a_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Vi84a_METADATA.txt
#
#
# 490 xml_src\drama\Vi\ViFU.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\ViFU_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\ViFU_METADATA.txt
#
#
# 491 xml_src\drama\Vi\Viht.xml
# Hentet rollelisten
# > Fant ingen replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Viht_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Viht_METADATA.txt
#
#
# 492 xml_src\drama\Vi\Viht_noter.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\drama\Vi\Viht_noter_SANERT.txt i xml_output\drama\Vi
# >> Metadata opprettet: xml_output\drama\Vi\metadata\Viht_noter_METADATA.txt
#
#
# 493 xml_src\sakprosa\P1841-1905ht.xml
# > Ingen rolleliste.
# > Fikset replikker.
# > Fjernet uønskede tagger.
# > Erstattet feltkoder med ASCII.
# > Formatert.
# >> Opprettet xml_output\sakprosa\P1841-1905ht_SANERT.txt i xml_output\sakprosa
# >> Metadata opprettet: xml_output\sakprosa\metadata\P1841-1905ht_METADATA.txt
#
#
#
# Log: 986 files parsed to text. 0 files failing to parse.

# %% [markdown]
# ## Logg

# %%
print("Gjorde om",i+1,"dokumenter til rentekst fra",len(paths)+1,"XML-filer. Vi fikk",y,"encoding-feil.",face)
if errors:
    errors
# Out:
# Gjorde om 494 dokumenter til rentekst fra 494 XML-filer. Vi fikk 0 encoding-feil. :)

# %% [markdown]
# ~~UnicodeEncodeError: 'charmap' codec can't encode character '\u203b' in position 1180: character maps to undefined. Denne karakteren her: ※ (Fixed)~~
#
# ~~Ok, fra 3 feil til 1 etter å ha konvertert "&ergo;" til "ɔ"!~~
# Header
# FIX: Glemte å manuelt sette output til encoding="utf-8"... men nå skriver alle filer!
#
# ~~TODO: Mange korreksjoner og sånne ting som gjemmer seg blant teksten i tags.~~
#
# ~~TODO: De variablene under må dekonstrueres og deler av dem må stappes inn igjen inn i en ny fil under metadata~~.

# %% [markdown]
# # Ferdig!
# De rene tekstfilene skal nå finnes under .../xml_output/*, samt metadata i tilhørende mappe. Med mindre du fikk feil i scriptet over. Eller om noe annet gikk galt.
#
# ### TODO
# Ja, det er jo selvfølgelig HTML-kommentarer (< !-- -->) i *noen* av disse.. de må fjernes.
#
# ___
#
# # Testing
# Ting under denne overskriften er bare å se bort fra med mindre du skal teste nye greier eller andre løsninger. Obs - dette fungerer kun etter å ha kjørt hele koden en gang.
#
# Prøver nå å finne ut hvorfor enkelt-ier (" i ") forsvinner i prod...

# %%
raise KeyboardInterrupt # Stooooopppp.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-039d79b1541b> in <module>
# ----> 1 raise KeyboardInterrupt # Stooooopppp.
#
# KeyboardInterrupt:

# %%
item = 91 # 

thing = paths[item]
with open(thing, "r", encoding="utf-8") as file: # Åpne stien, les, med encoding UTF8
    # Read each line in the file, readlines() returns a list of lines
    content = file.readlines()
    # Combine the lines in the list into a string
    content = "".join(content) # Variabel content får innholdet
content = BeautifulSoup(content, from_encoding="UTF-8") # Content er content som bs4-objekt...

# %%
outputs[item] = outputs[item] + ".xml"

# %%
# Filhåndtering II - Lag ny sti
frags = outputs[item].split('\\') # Splitt outputstrengen for sti
if "xml" in frags[2]: # Hvis filen er 3 ned, altså vi finner xml-filen her (eks. xml_src\dikt\~.xml)
    dirName = frags[0]+"\\"+frags[1] # Dirname blir 2 dyp (xml_output\DIRNAME\)
    metaName = frags[2] # Trenger et navn på filen
else: # OBS!! OBS!! Hvis filen IKKE er 3 ned ANTAR vi at den er 4 ned, slik som de(n) er i dramafolderen.
    metaName = frags[3] # Navn på filen
    dirName = frags[0]+"\\"+frags[1]+"\\"+frags[2] # Dirname blir 3 dyp (xml_output\drama\DIRNAME\)
    archDir = frags[0]+"\\"+frags[1] # FAILSAFE for DRAMA: Drama er ett hakk lengre ned i hierarkiet enn alt annet. Skap mappe for å ta drama
    #OBS - koden her ANTAR at senteret ALLTID følger samme praksis. Koden må endres om praksis endres.
    if not os.path.exists(archDir): # Hvis subfolder ikke finnes (eks.\drama\BE\)
        os.mkdir(archDir) # Skap den

metaFolder = dirName+"\\metadata" # Vi forbereder en metadatafolder ett steg under stien vi lagde over
metaName = metaName[:-4] # Strip . x m l. Bruker ikke outputs[i] fordi den gir hele stien, metaName er fragment
metaFile = metaFolder+"\\"+metaName+"_METADATA.txt" # Metadatafilen skal få samme filnavn med _metadata-suffiks
outputs[item] = outputs[item][:-4] # Strip 4 tegn fra slutten av hver streng for å få bort .xml (4. 3X 2M 1L)
# Create target Directory if don't exist
if not os.path.exists(dirName): # Hvis folderen ikke eksisterer
    os.mkdir(dirName) # Lag folderen
    os.mkdir(metaFolder) # Legg metadata-folder inne i den igjen
name = outputs[item]+filsuffiks+filformat # Outputfil får navnet X_SANERT.txt
# XML til TXT - Det er her vi skal sette inn X FOR EACH for å redigere XML-filene.

# %%
# Hent strukturer vi skal beholde
try:
    titlestatement = content.find("titlestmt") # Finn title statement
    titlestatement.extract() # Hent (og fjern) title statement-delen
except:
    print("> Ingen title statement.")

try:
    filedescription = content.find("filedesc") # Finn filbeskrivelsen
    filedescription.extract() # Hent (og fjern) filbeskrivelsen
except:
    print("> Ingen filbeskrivelse.")
try:
    castlist = content.find("his:hiscastlist") # Finn rollelisten
    castlist.extract() # Hent (og fjern) rollelisten
    print("Hentet rollelisten")
except:
    print("> Ingen rolleliste.")

# %%
castlist

# %%
target = content.body
target.insert_before(castlist)
content

# %%
# Slett tagger vi ikke skal beholde
if tag_hisdel == 2:
    z = 0
    try:
        for tag in content.findAll('his:hisdel'):
            tag.replaceWith(" ~~ %s ~~ " % a.string)
            z += 1
        if z > 0:
            print(">Erstattet",z,"hisdel-tagger med markdown-tagger.")
        else:
            print(">his:hisdel-tagger er ikke 0, men 0 ble fjernet...? Hva.")
    except:
        print("> Ingen hisdel-tagger å endre.")


try: # Her er kode for å endre & bevare replikker
    #speaker = content.findAll('his:hissp') # Finn alle replikker
    #for talker in speaker: # For hver av disse
    #    tag = content.new_tag("what") # Lag en ny, tom og intetsigende tagg
    #    tag.string = (talker['who']+": ") # Teksten i denne taggen er 'REPLIKKGIVER: '
    #    talker.insert_before(tag) # Sett elementet inn før replikken
    #    talker.unwrap() # Flytt alt innholdet i replikken ut og opp ett steg.
        # Husk at med denne metoden sletter vi alt i <speaker>-taggen.
    speaker = content.findAll('speaker') # Finn alle replikker
    for talker in speaker: # For hver av disse
        tag = content.new_tag("dummytag") # Lag en ny, tom tagg
        tag.string = (talker.string) # Inkonsekvent punktum- og mellomromsføring fører til at vi ikke kan legge ->
                                    # mellomrom eller punktum etter denne.
        talker.insert_before(tag) # Sett elementet inn før replikken
        talker.decompose() # Ødelegg kildeelementet for å hindre dobbelt opp
        # Denne metoden bruker <speaker>-taggen og ignorerer det i 'who'
    print("> Fikset replikker.")
except:
    print("> Fant ingen replikker.")

# %%
try:
    for tag in tags_to_erase:
        to_remove = content.find_all(tag) # Finn alle instanser av taggen
        for remove in to_remove: # For hver av disse
            remove.decompose() # Fjern taggen og innholdet helt
    print("> Fjernet uønskede tagger.")
except:
    print("> Fant ingen uønskede tagger.")

# %%
content = str(content) # CONTENT ER NÅ STRING - STRINGMETODER FUNGERER, BS4-METODER FUNGERER IKKE
z = 0 # Tell fra 0 i z
for code in codes: # For hver kode
    if code in content: # Hvis koden finnes i teksten
        content = content.replace(code,asciis[z]) # Erstatt koden med ascii
        #print('Erstattet',code,'med',asciis[z]) # Print bekreftelse
    z+=1 # Neste kode/ascii etter å ha sjekket hver kode
print("> Erstattet feltkoder med ASCII.")

# %%
if replacemode == "ordinary":
    content = content.replace("\n"," ") # Slett newline og erstatt med mellomrom 
    content = content.replace("'“'","")
    content = content.replace("&dash;","-")
    content = content.replace("&"," & ")
    content = content.replace("& &"," & ")
    content = content.replace(". &",".")
    #content = content.replace(" > ","")
    content = content.replace("'\"'", "")

# %%
content = re.sub('<[^<]+>', "", content) # Slett alle resterende tagger UTEN å røre innholdet

# %%
content = re.sub('\s+',' ', content) # Korriger alle instanser av multimellomrom til enkeltmellomrom

# %%
try: # Prøv å skrive til disk
    f = open(name, "w", encoding="utf-8") # Ikke glem encoding="utf-8", sånn som jeg gjorde.
    f.write(content) # Skriv innholdet i content-variabelen
    f.close()
    print(">> Opprettet",name,"i",dirName)
    x+=1
except: # Hvis vi møter på feil, rapporter kilden
    print("XXX FILFEIL!",thing)
    f = open(name+"_ERROR", "w", encoding="utf-8")
    f.write("XXX Filfeil!")
    f.close()
    errors.append(name)
    y+=1
metadata = str(filedescription)+str(titlestatement)
try: # Prøv å skrive metadata! til disk
    f = open(metaFile, "w", encoding="utf-8") # Ikke glem encoding="utf-8", sånn som jeg gjorde.
    f.write(metadata) # Skriv innholdet i metadata-variabelen
    f.close()
    print(">> Metadata opprettet:",metaFile)
    x+=1
except: # Hvis vi møter på feil, rapporter kilden
    print("YYY FILFEIL!",thing)
    f = open(metaFile+"_ERROR", "w", encoding="utf-8")
    f.write("YYY Metadata filfeil!")
    f.close()
    errors.append(name)
    y+=1
i+=1
if i > 70:
    raise KeyboardInterrupt
print("\n")
print("\nLog:",x,"files parsed to text.",y,"files failing to parse.")
if y > 0:
    face = ":("
else:
    face = ":)"

# %%
#content = re.sub(" . ", " ", content)#AHA! FANT DEG
content = content.replace(" . ", " ")
content = content.replace(" < ", "")

# %%
content
